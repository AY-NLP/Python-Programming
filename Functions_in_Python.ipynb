# %% [markdown]
# <a href="https://colab.research.google.com/github/AY-NLP/Python-Programming/blob/main/Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 'def' is the keyword for defining a function

# %%
def my_name():
  print("my name is Joy")
  # removed the recursive call to my_name()

# %%
my_name()
# Out:
# my name is Joy

# %%
# Arguments

# %%
def weather(good):
  print("The weather is {good}")
  if weather == 'good':
    print("go outside")
  else:
    print("stay inside")

# %%
weather('good')
# Out:
# The weather is {good}
# stay inside

# %%
def cat(mood):
  print(mood)
  if mood == 'happy':
    print("purr")
  else:
    print("meow")

# %%
cat('happy')
# Out:
# happy
# purr

# %%
cat('sad')
# Out:
# sad
# meow

# %%
# Define function
def greeting(name, department):
  print("Hello, " + name)
  print("You are part of " + department)

# %%
# Keyword argument
greeting("Joy", "AI developer")
# Out:
# Hello, Joy
# You are part of AI developer

# %%
# Keyword argument
greeting("Ayo," ,"Software engineering")
# Out:
# Hello, Ayo,
# You are part of Software engineering

# %%
def student(firstname, lastname):
    print(firstname, lastname)

# %%
  # Keyword argument
student(firstname='Joy', lastname='Olusanya')
# Out:
# Joy Olusanya

# %%
# Arbitrary Keyword Arguments, **kwargs

# %%
def my_function(**Naomi):
    print("Her last name is " + Naomi["lastname"])

my_function(fname="Joy", lastname="Olusanya")
# Out:
# Her last name is Olusanya

# %% [markdown]
# Returning Values

# %%
def add1(a):
  b = a + 1
  return b

# %%
print(add1(5))
# Out:
# 6

# %%
def add1(a):
  b = a + 1
  return b

# %%
c = add1(5)
print(c)
# Out:
# 6

# %%
def add1(a):
  b = a + 1
  return b

# %%
d = add1(8)
print(d)
# Out:
# 9

# %%
def area_traingle(base, height):
  return (base*height)/2

# %%
area_a = area_traingle(5, 4)
area_b = area_traingle(7, 3)
print("The sum of both area is:" + str(area_a + area_b))
# Out:
# The sum of both area is:20.5

# %%
def my_function(x):
  return 10* x

print(my_function(5))
print(my_function(15))
print(my_function(10))
# Out:
# 50
# 150
# 100

# %% [markdown]
# Default Parameter Value

# %%
def my_function(country = 'Nigeria'):
  print("I am from " + country)

my_function("Ghana")
my_function("Turkey")
my_function()
my_function("USA")
# Out:
# I am from Ghana
# I am from Turkey
# I am from Nigeria
# I am from USA

# %%
def my_function():
  print("Hello from a function")

# %%
my_function()
# Out:
# Hello from a function

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age
AYO = Person("John", 36)

print(p3.name)
print(p3.age)
# Out:
# John
# 36
